# %%
# Task 1: Data Cleaning & Preprocessing with Titanic Datasset

import pandas as pd

# Dataset
df = pd.read_csv("Titanic-Dataset.csv")


print("Original Dataset Shape:", df.shape)
print("\nMissing Values Before Cleaning:")
print(df.isnull().sum())


# Handle Missing Values

# Fill missing Age values
df['Age'].fillna(df['Age'].mean(), inplace=True)

# Fill missing Embarked
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Fill missing Cabin values
df['Cabin'].fillna('Unknown', inplace=True)


# 2. Remove Duplicates

duplicates = df.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicates)

df.drop_duplicates(inplace=True)

# 3. Convert Data Types

df['Survived'] = df['Survived'].astype(int)
df['Pclass'] = df['Pclass'].astype('category')
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')

# 4. Rename Columns

df.rename(columns={
    'PassengerId': 'Passenger_ID',
    'Pclass': 'Passenger_Class',
    'SibSp': 'Siblings_Spouses',
    'Parch': 'Parents_Children',
    'Fare': 'Ticket_Fare'
}, inplace=True)

# Final Output

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())

print("\nUpdated Column Names:")
print(df.columns.tolist())

print("\nFinal Dataset Shape:", df.shape)

# Save New Dataset
df.to_csv("Titanic_New.csv", index=False)

print("\nData Cleaning Completed")
print("Cleaned file saved as: Titanic_New.csv")
# Out:
# Original Dataset Shape: (891, 12)
#
# Missing Values Before Cleaning:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Number of Duplicate Rows: 0
#
# Missing Values After Cleaning:
# Passenger_ID        0
# Survived            0
# Passenger_Class     0
# Name                0
# Sex                 0
# Age                 0
# Siblings_Spouses    0
# Parents_Children    0
# Ticket              0
# Ticket_Fare         0
# Cabin               0
# Embarked            0
# dtype: int64
#
# Updated Column Names:
# ['Passenger_ID', 'Survived', 'Passenger_Class', 'Name', 'Sex', 'Age', 'Siblings_Spouses', 'Parents_Children', 'Ticket', 'Ticket_Fare', 'Cabin', 'Embarked']
#
# Final Dataset Shape: (891, 12)
#
# Data Cleaning Completed
# Cleaned file saved as: Titanic_New.csv
# /tmp/ipykernel_446/1511267916.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# /tmp/ipykernel_446/1511267916.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# /tmp/ipykernel_446/1511267916.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna('Unknown', inplace=True)
